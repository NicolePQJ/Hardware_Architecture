# %%
import os, inspect, sys, subprocess, yaml, pprint, math, pickle, shutil, signal, math, time, argparse
from copy import deepcopy

# %%
path =  "/../architecture/new_arch.yml"

# %%
result = run_accelergy(architecture=path,)
print(result.ert)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = run_accelergy(architecture=path,)
#       2 print(result.ert)
#
# NameError: name 'run_accelergy' is not defined
